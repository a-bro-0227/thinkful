# %%
# 1 nyc baby name data from CSV

import pandas as pd

# also possible to save to gdrive and load from there, or some other place.
df=pd.read_csv('https://tf-assets-prod.s3.amazonaws.com/tf-curric/data-analytics-bootcamp/nyc_baby_names.csv')

df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11345 entries, 0 to 11344
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year of Birth         11345 non-null  int64
#  1   Gender                11345 non-null  object
#  2   Ethnicity             11345 non-null  object
#  3   Child's First Name    11345 non-null  object
#  4   Count                 11345 non-null  int64
#  5   Rank                  11345 non-null  int64
#  6   Gender.1              11345 non-null  object
#  7   Ethnicity.1           11345 non-null  object
#  8   Child's First Name.1  11345 non-null  object
#  9   Sub1                  11345 non-null  object
#  10  Sub2                  11345 non-null  object
#  11  Unnamed: 11           0 non-null      float64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 1.0+ MB
#    Year of Birth  Gender  ...                        Sub2 Unnamed: 11
# ...

# %%
pd.crosstab(index = df, columns=["Gender", "Ethnicity"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1669     try:
# -> 1670         blocks = form_blocks(arrays, names, axes)
#    1671         mgr = BlockManager(blocks, axes)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in form_blocks(arrays, names, axes)
#    1756     if len(items_dict["ObjectBlock"]) > 0:
# -> 1757         object_blocks = _simple_blockify(items_dict["ObjectBlock"], np.object_)
#    1758         blocks.extend(object_blocks)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in _simple_blockify(tuples, dtype)
#    1800     """
# -> 1801     values, placement = _stack_arrays(tuples, dtype)
#    1802
#
# ...

# %%
# 2 tweets in json

import pandas as pd

df = pd.read_json('https://tf-assets-prod.s3.amazonaws.com/tf-curric/data-analytics-bootcamp/tweets.json')

df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1018 entries, 0 to 1017
# Data columns (total 29 columns):
# contributors                 0 non-null float64
# coordinates                  3 non-null object
# created_at                   1018 non-null datetime64[ns]
# entities                     1018 non-null object
# extended_entities            159 non-null object
# favorite_count               1018 non-null int64
# favorited                    1018 non-null bool
# geo                          3 non-null object
# id                           1018 non-null int64
# id_str                       1018 non-null int64
# in_reply_to_screen_name      1 non-null object
# in_reply_to_status_id        0 non-null float64
# in_reply_to_status_id_str    0 non-null float64
# in_reply_to_user_id          1 non-null float64
# in_reply_to_user_id_str      1 non-null float64
# is_quote_status              1018 non-null bool
# lang                         1018 non-null object
# ...

# %%
# 3 from sql

import pandas as pd
from sqlalchemy import create_engine

host = "142.93.121.174"
username = "dsbc_student"
password = "7*.8G9QH21"
port = 5432
dbname = 'department_of_education'

engine = create_engine('postgresql://{}:{}@{}:{}/{}'.format(
    username, password, host, port, dbname))
                       
                       
df = pd.read_sql_table('finance', con=engine)                      
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1275 entries, 0 to 1274
# Data columns (total 13 columns):
# capital_outlay_expenditure      1275 non-null int64
# enroll                          1224 non-null float64
# federal_revenue                 1275 non-null int64
# id                              1275 non-null object
# instruction_expenditure         1275 non-null int64
# local_revenue                   1275 non-null int64
# other_expenditure               1224 non-null float64
# state                           1275 non-null object
# state_revenue                   1275 non-null int64
# support_services_expenditure    1275 non-null int64
# total_expenditure               1275 non-null int64
# total_revenue                   1275 non-null int64
# year                            1275 non-null int64
# dtypes: float64(2), int64(9), object(2)
# memory usage: 129.6+ KB
#    capital_outlay_expenditure  enroll  federal_revenue               id  \
# ...
